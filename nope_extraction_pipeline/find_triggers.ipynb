# %%
from tqdm import tqdm

# %%
import os
import pandas as pd
#import numpy as np
import spacy


from io import StringIO
from spacy.tokens import Doc
from csv import QUOTE_NONE

CONLL_COLUMN_NAMES = ["idx", "token", "lemma", "upos", "xpos", "morph", "head", "dep", "enhanced", "misc" ]

class CoNLLReader(object):

    def __init__(self, path):
        self.conll_file = open(path, "r")
        self.nlp = spacy.load("en_core_web_sm")


    def __iter__(self):
        return self

    def __next__(self):
        with StringIO() as buffer:
            metadata = {}
            initial = True
            for line in self.conll_file:
                if line == "\n":
                    if initial:
                        continue
                    else:
                        break

                initial = False

                if line[0] == "#":
                    key, val = line[2:].split("=", 1)
                    key = key.strip()
                    val = val.strip()
                    metadata[key] = val

                else:
                    buffer.write(line)

            buffer.seek(0)
            d = pd.read_csv(buffer, sep="\t", names=CONLL_COLUMN_NAMES, quoting=QUOTE_NONE, dtype="str", keep_default_na=False, na_values=[])
            if len(d) < 1:
                raise StopIteration
            d = d.astype({"head": "int32"})

        try:
            doc = Doc(self.nlp.vocab, words=list(d["token"]))
        except:
            print(d.dtypes)
            print(d)
            print(d["token"])
            raise StopIteration

        for token, lemma in zip(doc, d["lemma"]):
            token.lemma_ = lemma


        for token, tag in zip(doc, d["xpos"]):
            token.tag_ = tag

        for token, dep in zip(doc, d["dep"]):
            token.dep_ = dep

        for token, head in zip(doc, d["head"]):
            if head > 0:
                token.head = doc[head-1]

        return doc, metadata

# %%
from change_of_state_better import find_change_of_state
from continuation_of_state_better import find_continuation_of_state

# %%
from comparatives import check_comparative
from clefts import check_cleft

# %%
from embedded_question import check_sentence_for_embedded_question 
from factives import check_sentence_for_factives, check_sentence_for_quote

# %%
from lib.conll_reader import CoNLLReader

# %%
dataset_path = "../datasets/unanswerable_questions_dev.jsonl"

# %%
import json 
import pandas as pd

# %%
qs = pd.read_csv('/Users/nehasrikanth/Documents/question-gen/seed_annotation/round_2/annotator_questions_masterlist.csv')

# %%
with open(dataset_path) as f:
    for line in f: 
        text = line.rstrip("\n").split(",")[0]
        if text.split()[0] not in set(['who', 'what', 'when', 'where', 'why', 'how', 'which']):
            continue
            
        nlp_text = nlp(text)
        print(nlp_text)
#         if 'POS' in [t.tag_ for t in nlp_text]:
#             print(text)
        
#         if check_sentence_for_embedded_question(nlp_text)[0]:
#             print(text)
# Out:
# when was the writ watch invented by who
# when do new chapters of owari no seraph come out
# where does the last name painter come from
# what are the challenges faced by the cotton textile industry of ahmedabad
# which of the below feature makes the ram not suitable for the persistent storage
# what is the life cycle of a centipede
# which is the nearest country north of egypt
# what is the un declaration on the rights of indigenous peoples
# what is selena gomez most popular tv show
# when do they announce the next winter olympics
# when was each region added to the united states
# where is cars 3 supposed to take place
# what is the origin of the name dara
# who is the national artist for visual who was conferred and died of the same year 1999
# where was the movie coming to america shot
# what happened to the son in war of the worlds
# who played scotty in the new star trek movie
# who played the agent in i can only imagine
# who played the ice cream man in this is us
# who is playing in the western conference finals
# who plays the ex girlfriend on ap bio
# where is the vertebral column located in the human body
# where does the term skin in the game come from
# where did the last name weaver come from
# when did the 49ers last won a superbowl
# who sang mary's boy child in 1957 and 1978
# who owns the washington post and new york times
# who played the girl in the pit in silence of the lambs
# where is mom and dad or where are mom and dad
# who explained the workings of the human body
# what game show host has a black belt
# what is the taxonomical significance of the gram stain method
# who are the 12 cylons in battlestar galactica
# when do subtitles start in the passion of the christ
# who sang the song angel of my life
# when is the next step up movie coming out
# who is the main character in black midas
# which is not a power of the united states congress
# what is the difference between intramural and interscholastic sports
# where was hallmark movie a country wedding filmed
# where does hou safely hide after escaping jail
# who has the number one pick in nba draft
# who did the united states not have problems with on the high seas
# who attended all the three round table conferences
# who was the song michelle by the beatles written for
# when are the olympics going to be in canada
# when does the 15 vat come into effect
# who got eliminated in dance champions 29 october 2017
# how many hilton hotels are there in the uk
# when did the modern world system approximately end
# who has been fined the most in the nfl
# how many lucky charms marshmallows are in one box
# why are there different time zones in australia
# who abolished slave trade in nigeria and in what year
# what is the role of a canadian senator
# where can a master at arms be stationed
# what is head to head in dream 11
# how many medals has the american team won
# who continues to exist according to the zhou chinese
# how many students audition for laguardia high school
# what is the difference between an unknown sample and a control
# who has won table tennis national championship recently
# where are the stars of my three sons now
# who got the best record in the wnba
# what is the difference between genotype and allele frequencies
# what is the average temperature in ecuador in january
# what is the meaning of fire and fury
# where is ikot okpudo located in akwa ibom state
# where was the last scene in shooter filmed
# how often can you have a halls cough drop
# who warned that a president who could be reelected again and again may easily become a king
# who is dwayne johnson related to in wwe
# how many cities and towns are in the united states of america
# who played chris pines secretary in wonder woman
# which is not true about the chinese horse
# where am i on the steelers waiting list
# which of the following is not a part of a microbes genome
# where does the girl who was supposed to die take place
# who play the wilson sisters in white chicks
# how does the system of checks and balances enable congress to control the presidents foreign policy
# what is the difference between ti 84 plus and silver
# where does bank of america invest its money
# what was the climate like in ancient egypt
# where is a unitary system of government found
# where does the saying brownie points come from
# where was the movie spies like us filmed
# what is the meaning of the name baba
# who sits in front of president during state of the union
# where did the name olive garden come from
# which of these is best description of passive transport
# who sings the song hooked on a feeling
# who was the first rock band to have a video game made featuring their music and images
# what rough beast its hour come at last slouches towards bethlehem to be born
# how are the chief justice and other judges of the supreme court appointed
# who buys the most fireworks in the world
# where is the bulk of medicaid funds spent
# which locks are located on the north end of the panama canal
# where was the american flag placed in 1909
# where does the last name agustin come from
# when did the first iphone come out and how much was it
# who are the first class citizen of bangladesh
# which of the following is caused by a member of the rickettsias
# how do devices support multiple technologies such as wifi 3g and 4g
# who could it be believe it or not it's just me
# where is the cast of days of our lives
# when did the nfl start playing the national anthem
# when did cat on a hot tin roof take place
# who was involved in the great wall of china
# what programs and actions the eu has taken to help create this european culture
# where does the digestion of food take place
# who has won entertainer of the year the most times
# who played the joker in the dark night rises
# who discovered that genes are located on chromosomes
# who has the most real power in the house of representatives
# who sings on my way back to georgia
# which of the following was the initial objective of the civil rights movement in america
# which of the following describes the zimmerman telegram of 1917
# where does will find the sign of stone
# why does one ok rock sing in english
# where can single letter variables can be used
# when does the new season of star trek begin
# what factors led to the rise of national economies
# where do the atlanta falcons play next week
# how did new mexico get its name and nickname
# who is the person who asks questions in a debate
# where is the wailing wall and why is it a holy spot
# what time is nbc nightly news on in california
# which of these is japan’s worst environmental issue
# who plays kyle's mom on csi miami
# how many weeks in nfl season including playoffs
# how was it discovered that a deletion in the ccr5 gene could affect hiv tropism
# what are the three major climate zones found on planet earth and how are they identified
# where do we go from here the song
# how many chapters are in son by lois lowry
# when is the segment making a contribution to the corporate bottom line
# when does brawl stars come to the usa
# who has sold the most country albums of all time
# where did the last name villegas originate from
# when does death wish with bruce willis come out on dvd
# who are bad guys in wreck it ralph
# how much money did germany spend in ww2
# what happens if one tries to hide out in another state after being charged with a crime constitution
# who is the most downloaded artist of all time
# which of the following describes the element k
# what is the oldest age to be in the olympics
# what was the problem with requiring a unanimous vote of the states
# what is the number one university in the united states
# what document produced during the french revolution was ignored by the committee of public safety
# how many indian elephants are there in the world
# when did the amazon great indian festival 2017 begin
# when is fairy tail ep 278 coming out
# who won gold medal at world weightlifting championship held in united states
# who became one of the most popular monarchs in the 16th century
# which of the following is not a true statement about amicus curiae briefs
# who were the principal musicians of the jazz avant-garde
# where are stem cells found in our body
# who plays young lydia in one day at a time
# who made uk passports before de la rue
# where did the royal family go to school
# what is the meaning of safiya in urdu
# how to start a wikipedia page for someone
# when does an ember in the ashes movie come out
# who is a pretty little liars season 7
# what is the means of strange in hindi
# how many uk lottery tickets are sold each week
# how did the panic of 1819 create conflict between members of the democratic-republican party
# how old do you have to be to work at pacson
# which of the following represented the general path of american foreign policy
# who are the characters of every child is special
# how many ncaa football games in a season
# when does white fence farm close for the season
# how do i get to dubuque from here
# what is a broadcast domain and collision domain
# which of the following is used by 802.1x for network access control
# when did merchants from the arabian peninsula begin to settle in east africa
# when was the last time clemson was shut out
# who was rated number 1 on the 2015 fortune 500's 40 under 40
# what term is used to describe inflammation of the lung
# when was spruce grove composite high school built
# who became the world heavyweight champion in november 2015
# when does the thinning new world order come out
# when was the big mac released in the uk
# who is this doing this synthetic type of alpha beta psychedelic funkin' lyrics
# who has a green white and red flag
# what cathedrals stand on the bank of the mersey
# when did tom brady play in the pro bowl
# how much does a pret a manger franchise cost
# who is the main character in the book drama
# what is meant by a bread line and direct relief
# what types of writing did the romantics create
# what sports does jamaica play in the olympics
# how long is ex on the beach on for
# who wrote star of the story by heatwave
# who is credited with describing the proper form for greek tragedy
# how did the warlord era contribute to the start of the chinese civil war
# who has a net worth of 500 million
# what is the correct chronological order of west african kingdoms
# how did the u.s. navy make an immediate difference in the war
# when does jocelyn wake up in the book
# when did major and minor scales become the basis for composition
# what to do when us flag touches ground
# what are the names of the kings two sons
# when was the local government system under the devolution of power plan 2001 inaugurated
# who wrote the dong mary did you know
# where is turkey commodity largely produced in our country
# what is the reasonable person standard in negligence law
# what was left of spain's empire by 1914
# how did romans navigate from place to place
# what are the words of fairytale of new york
# which among the following browsers have support to html5
# which one of these might appear in an evalution of a poem
# who was accepted as a student by gautama
# when does back to the future part 4 come out
# where was the movie mighty joe young filmed
# what led to the development of the blues
# where is the industry of news print paper situated
# who was the little girl in walking tall
# how much of the world's cocoa comes from ghana
# who produced the first ever records on the trojan label
# who said the best game ever for the sydney 2000 olympic game
# how do they cut a person in half trick
# how many dc voltage value use in electro-pneumatics
# who could it be it's just me
# which surah in the quran has 2 bismillah
# what happened in the last episode of seinfeld
# who is rab in harry potter half blood prince
# when is the next suits episode coming out
# which of the following is not part of the philosophy of the green house
# when does the next ratchet and clank come out
# who played kathleen on fresh prince of bel air
# who has nightmares about the witches in macbeth
# why did walt disney create the walt disney company
# who plays norman bates brother on bates motel
# when did the assault rifle become available to the public
# which 2d shape has the most number of axes of symmetry
# when is the next episode of citizen khan coming out
# when does shadowhunters season 1 come out on dvd
# when was the first testicular guard used in cricket
# where did they film high school musical two
# who has the rights to alice in wonderland
# what is the lowest recorded temperature on mount vinson
# when is the next tangled the series episode coming out
# how do i get to warsaw missouri from here
# what is the only fruit that does not have seeds
# who lives who dies who tells your atory lyrics
# who has played for the most nba teams
# when did hawaii become a state and why
# who has scored the most touchdowns this year
# what was the soviets response to the truman doctrine
# where do honey bees live in the world
# when does karev die in grey's anatomy
# why did alex and ellen break up on family ties
# how much is john incredible pizza to get in
# what platform is sandringham line at flinders st
# what is the string of 882 islands extending southwest from the southern tip of florida known as
# which biome is characteristic of central sub saharan africa nearest the equator
# where is most vascular tissue found in plants
# how common is the word in the english language
# who wrote the poem the woods are lovely dark and deep
# who holds the record for longest motorcycle jump
# why is the new disney movie called coco
# where no man has gone before episode cast
# where is deforestation occurring in the united states
# where does the nitrogen for this fertilizer come from
# where is jj's husband on criminal minds
# when is the rock n roll hall of fame
# where was atticus finch born in to kill a mockingbird
# where have the good guys gone to hideaway
# when does the soul train music awards come on tv
# where did the easter eggs and bunny come from
# what guides santa home after he has delivered presents
# how do you think south africa compared with singapore
# what was going on in 1954 in the us
# who occupied the holy land after the 8th crusade
# which of the following is the federal governments biggest source of tax revenue
# who is the only bowler to take hattrick in test cricket
# what are the five pillars of islam in arabic
# when is the next time easter falls on april 11th
# what is the moral of cat in the hat
# when does the new episode of criminal minds air
# where is a pulse generator most commonly found in a car
# who were the church fathers and what did they do in the catholic church
# when calls the heart season 3 episode 12
# how old is the vice president of the united states
# where is the stanley cup being held this year
# how many credits for a bachelor's degree in science
# who plays eddie's father on blue bloods
# which of the following areas has nothing to do with the reinforcing effects of drugs
# which of the following was not a major battle of world war i
# which of the following is the part of the bible meaning the law
# who plays sofia in when calls the heart
# where is australia’s closest french speaking country
# which of the following was a result of the connecticut compromise
# when is the solar eclipse passing through kentucky
# what awards did the harry potter movies win
# where have you been all my life arthur alexander
# who was the league of nations made up of
# which of the following statistical quantities are measures of central tendency
# what are the kinds of dance and its definition
# where are the orcs made in lord of the rings
# when was the last time penn state was #2
# who is jessie's girl on breaking bad
# where do car factories tend to be located and why
# what did the american flag look like in 1896
# where is episode 13 of attack on titan
# what is the legislature of the united states called
# when would a post card not be needed
# what was the relationship between japan’s emperors and military leaders
# how do i loathe thee let me count the ways shakespeare
# how many gears does an electric car have
# how big is the celebrity big brother house
# where was the bill of rights written at
# who wrote the story of my life by neil diamond
# when does the i come before the e
# which action shortens the fibers of the serratus anterior
# what was taking place before the industrial revolution
# when was the first building built in dubai
# when does season 2 of wolf hall start
# how does the romanesque bust reliquary reflect another culture's influence
# who plays mad max on johnboy and billy
# what part of new york likes the jets
# which regions on earth have seasons tied to the amount of rainfall
# which of the following periods provided particularly high returns to stock​ investors
# how would you represent g0 in the cell cycle of a neuron
# what are the different aspects of community health
# who are you and what are you doing here citation
# where are the locations for the ncaa basketball tournament
# how many states in india have atleast one international border
# which of these rights was limited by the sedition act of 1918
# what kind of energy must be added or removed to change the state of matter
# what channel is bbc three on direct tv
# where is graphic design used in architecture and interior design
# why do you die when you lose blood
# who drove #9 in nascar in 2017
# how many departments are there within the british ministry of magic
# how do buddhism and jainism present new challenges to traditional vedic culture in india
# when does the next marvel runaways episode come out
# where does the bay area get its electricity
# where does the carbon in organic molecules come from
# what are the different types of diet plans
# which of the following is not considered characteristic of a type 1 diabetic in dka
# how many states are north of the southernmost point of canada
# where is national flag hoisted on republic day
# which two principles are the foundation of every states constitution
# what type of venom does a fer de lance have
# where can you shoot a gun in delaware
# who makes the most money in professional sports
# who pioneered the use of the scientific method in chemistry
# who do you think you are book pdf
# where does the national security council get their information
# how do you get a black belt in jiu jitsu
# what was the girl poisoned with in sixth sense
# who can be buried at fort indiantown gap
# who held political power in the southern colonies
# which of the following was a significant innovation of lowell mills
# which of the following are si units of young's modulus
# where is carbohydrate converted to glucose through the process of digestion
# which element is not a core component of the iso 27002 standard
# what does canada and us have in common
# which of the following events led most directly to the end of world war ll in europe
# who covered stuck in the middle with you
# who plays jekyll in once upon a time
# who sings the song how do you like your love
# which two choices describe the purpose of the hsi filter
# who was the king of england at the time the house of the seven gables was built
# what is the name of the oldest part of the university of paris
# who plays sheldon's mother on the big bang theory
# who plays jax's sister in sons of anarchy
# what is the theme of the book story of a girl
# who was the oldest person on the titanic
# who is considered the first great modern architect
# who plays stevie the bookie in still game
# when is time person of the year chosen
# which of the following social changes was a result of the second industrial revolution in the us
# who played betty in how i met your mother
# what order do patricia cornwell books go in
# who plays zac on the young and the restless
# how far is mechanicsburg ohio from columbus ohio
# who is easter named after and what are her symbols
# when the lights go out in the city journey
# where would you find a crawler or climbing lane
# how old are the members in why dont we
# what do the colors on the el salvador flag mean
# what kind of snakes live in south america
# what is the meaning of gynaecologist in hindi
# where do you place the glass slide at the end of lab
# who played the voice of mufasa in lion king
# what was the geographical significance of the location of judah and north israel
# which of the following will not decrease the demand for a commodity
# when was the last time metallica played milwaukee
# which city is called smart city in india
# who is credited as being the world's first published musicologist
# what is the advantage of genetic recombination as a mode of reproduction in bacteria
# how far is daytona fl from jacksonville fl
# what do you mean by health care services
# who did ku beat in football this year
# when it is winters in delhi how will the weather be in chennai
# what is rett's disorder and childhood disintegrative disorder
# where is the show my big fat fabulous life filmed
# where was you're only young twice filmed
# when did the drinking age change in the uk
# what is the average temperature on earth day and night
# what was the name of the confederate strategy during the civil war
# what does the american flag with one red strip mean
# how old was tommen when he married margaery
# what are the two large plains located on the eastern side of china
# where did will smith spent most of his days
# when was the last time real madrid lost at home
# where did the phrase tastes like chicken come from
# who is santa at melbourne carols by candlelight
# when was modem invented and in which country
# what is said to be the earliest gothic structure in france who was the director of its construction
# who gives the speech at the end of stuck on you
# who has man city drawn with this season
# when does dna replication occur in prokaryotes and eukaryotes
# what does the number at the beginning of sesame street mean
# who wrote broken home by 5 seconds of summer
# where did most of the fighting take place in ww2
# how far is the foul line from the basket in high school
# what are the major horse races in the us
# where has the phonograph been used throughout history
# where is so you think you can dance filmed 2017
# when do the north carolina tar heels basketball team play again
# how did the bessemer process help start the industrial revolution
# who won best actor and actress for the academy awards
# what was the population of new zealand in 1917
# what are the wishes in the monkey's paw
# how would you describe light generated by heating pure elements
# what happened in the last episode of ghost whisperer
# what is another lipid in the cell membrane
# what happened to angela in the deer hunter
# when does highschool of the dead season 2 come out
# who is running for governor of texas in 2018
# when will wolf girl and black prince be dubbed
# when was the last time kentucky basketball was unranked
# how many salesian schools are there in the world
# what region is the united states in the world
# who was exiled from florence for 9 years
# who invented the fastest computer in the world
# what is the names of the teenage mutant ninja turtles
# who wants to be a millionair board game
# how did nationalism influence the country of india
# what is (are) the purposes of a clear well in a water treatment plant
# who sang the songs in the movie i could only imagine
# where was the tv show the rifleman filmed
# when was i carry your heart with me written
# how old was olivia when she made grease
# how many miles is it to amarillo texas
# what group fought against the british control in india
# where is the cast of my name is earl now
# what do japan and north korea have in common
# what is the san andreas fault and where is it located
# what does the boy from karate kid look like now
# what is the headline of today’s miami herald
# what are examples of government agencies that address state problems
# who was the first missionary out of jerusalem
# when does season 8 of american restoration start
# what are the rules to curling in the olympics
# how old was the king of spain when he died
# when did the groundhog visit the white house
# when did the last person land on the moon
# when does damon realize that katherine is in elena's body
# when does psych the movie 2 come out
# where did the name florida georgia line come from
# when does the curious incident of the dog in the nighttime take place
# when did the scary movie it come out
# who inaugurated hosur 1 plant of ashok leyland
# who identified the two major engines of destruction as overconsumption and overpopulation
# why was the decision to leave french forces behind
# where does the last name sproul come from
# what are the most popular holidays in mexico
# which is not a spent conviction within the terms of the rehabilitation of offenders act 1974
# when does chance the rapper new album come out
# when is the real housewives of beverly hills on
# when do new episodes of modern family air
# who did the britons fight in the middle ages
# what is the second book in the mother daughter book club
# who won most of the battles over control of the mississippi river
# how are the southern african countries of malawi and botswana similar
# where is the most famous buddhist cave temple located
# how can we minimise or check the wastage of water in public life
# what is the qualification of a jurist for ijma
# which neighbouring country of india hosted the 14th saarclaw conference in october 2017
# which sequence of events would make a sedimentary rock
# how long is black panther going to be out
# when do owen and christina get back together season 5
# what was not one of the causes of the war of 1812
# which of the following statements about the laocoon group is false
# when did the daffodil become the emblem of wales
# who came up with the standard instrumentation for the dixieland band
# what are the 3 tributaries of the nile river
# who rents the top floor of the empire state building
# who played the libyans in back to the future
# what time do they color the river green
# who has won the most majors in tennis
# who played in the celebrity all star game 2018
# when does marnie come back to geordie shore
# who played dr. walcott on the big bang theory
# which of the following would result in an snp
# when does the new twenty one pilots album come out
# who got kicked off of ink master last night
# which of the following modes of selection can result in an evolutionary trend
# who served as the secretary of state under two different governors of texas
# where did sammy's sister go in bms
# where are the wettest areas of east africa
# when is the legal age to start working
# what is the first award presented at the oscars
# who played david brent's girlfriend in the office
# where was the one place that could generate all the wealth needed for the industrial revolution
# when is the new andi mack coming out
# who ends up with who in grey's anatomy
# how to say someone's name in korean
# when did the simpsons first air in uk
# which of the following was not one of the functions of the friedmans bureau
# which cellular layer of the epidermis is the only one capable of producing new cells
# who is peter in my family and other animals
# which of the following contain members that have chloroplasts in their cells
# who played baby betty barnaby in midsomer murders
# where did buddhism originate and where did it spread
# who fought in the french and indin war
# what percentage of eagle scouts join the military
# what is jvm and explain me the java memory allocation
# when was the last time the jacksonville jaguars were in the superbowl
# who read the file stored on web server
# who did dr armstrong kill in and then there were none
# how did india's nationalist movement change over time
# who is running for us senate in arizona
# how layers of sound occur in a piece of music
# why are arizona new mexico oklahoma and texas a region
# what rights did everyone have according to the declaration of the rights of man
# when does the new series of scorpion start
# when is project mc2 season 7 coming out on netflix
# who played the grandmother in while you were sleeping
# what powers did the federal government gained under the constitution
# who am i (whats my name)
# what channel is cbs on cable in arizona
# what was the last hurricane to hit washington dc
# when did baseball become america's national pastime
# how long is the new star waes movie
# which of the following terms are used to explain how the structure of logic relates
# where was final scene of expendables 3 filmed
# where was pirates of the caribbean 6 filmed
# who dies in criminal minds season 6 episode 2
# what is the restaurant at the end of the universe about
# why are the great lakes important to canada and the united states
# where are the taste buds located that are the most sensitive to sour substances
# how many fires are going on in southern california right now
# how far is hawthorne fl from gainesville fl
# who does joey end up with in joey
# what are the two biggest exports from mexico
# when does the show the doctors come on
# who owns the oil rigs in the gulf of mexico
# who said playoffs don't talk about playoffs
# who played mercy in orange is the new black
# who plays the scream killer in scary movie
# what do you call a person from york
# what kind of poison killed romeo and juliet
# who won the battles of iwo jima and okinawa
# how many human rights are there in uk
# what is the average size of an oyster
# who said experience is the mother of knowledge
# what is the criteria for a four star hotel
# how do i air drop from ipad to iphone
# who plays hugh grant's agent in the rewrite
# what is the mass number of the isotope with the symbol 3717cl
# when was the last time the 49ers went to the super bowl
# who was the first person to eat an apple
# which was not an element of the bushido code of the samurai warriors
# how many countries have english as first language
# when is ordinal scale coming out on netflix
# where do the meths live in altered carbon
# when did wendy's 4 for 4 start
# why is mayor poole on blue bloods in a wheelchair
# what is constructor in java what are its special properties
# who plays baby angelica on the l word
# who was the commander who directed military operations during much of ww2
# when were the urban sites of cahokia and chaco canyon in north america both abandoned
# where did the supreme court meet in its early history
# who maintained power in the governments of the colonies
# who did spain give the two areas of land to later
# which of the following was not a purpose of the propaganda campaign brainly
# when does alison dilaurentis come back for good
# what are the two basic ingredients for the synthesis of thyroid hormone
# which of the following formations is not a metamorphic unit in the llano region of central texas
# how many episodes of supergirl is superman in
# who was the killed in the open house
# when did red bull become popular in the us
# what is the current understanding of what hanny's voorwerp is
# when do wath comp go back to school
# where does the sun go during the night
# what league has home field advantage in world series
# what is (are) the major metabolic source(s) of acetyl coa
# when did the uk become part of europe
# why the english were founding colonies in north america in the early 1600s
# who developed a method for educating the hearing impaired
# how many cities make up the state of florida today
# what is the difference between great courses and great courses plus
# who played will smith's girlfriend in independence day
# who sang we had joy we had fun we had seasons in the sun
# how can the sarb use the cash reserves requirements and open market transaction to combat inflation
# who encouraged the beatles to wear matching suits and have matching haircuts
# who owns the crab boats on deadliest catch
# what happens to the light as the ocean increases in depth explain
# who put the dip in the dip de dip de dip
# when game of thrones season 7 episode 8 release date
# who plays young damon in the vampire diaries
# when does dan tell nathan he killed keith
# when did the egyptian ruler of lower nubia declare nubia independent from egypt
# how does a kangaroo care for its young
# what do justices do in the supreme court
# who went home from project runway last night
# when was the last time a number one seed won the ncaa tournament
# where does the last name moya come from
# which of the following games playground has bonus line
# when is season 2 of absolute duo coming out
# how old is rosalind from as you like it
# where did the modern era of manufacturing primarily begin
# when did revelations become part of the bible
# how does a non democratic state influence civil society
# what did the soviet union do in the cold war
# who are the baseball players in field of dreams
# who beat bobby flay on iron chef tournament of champions
# how long is the womens cross country race
# who drew the boundaries of the african countries
# which of the following is not a key characteristic of chinese gardens
# why was there a war between the hutu and the tutsi
# how many different types of abacus are there
# who plays the girl in the sandlot 2
# when does the personality of a physical person and a legal person being and end
# where is the island with bear grylls 2017 filmed
# what is the difference between primary and archaeological sources
# where was the movie my boyfriends dogs filmed
# who was the president of indian national congress during quit india movement
# who is being murdered on days of our lives
# where do the great treasures of ancient art belong
# which of the following is a keyword in java
# which decade saw the development of television and the beginnings of the space race
# when is the next episode of scandal coming on
# which of the following would be an example of limited government
# when do the kansas city chiefs play their first game
# who signs bills to become laws in india
# when did daylight saving time start in texas
# what historical event led to the creation of the 3rd amendment
# when did the double quarter pounder come out
# who holds most of the world's wealth
# who plays patroclus in troy fall of a city
# where did the saying don't kill the messenger come from
# what are the lyrics to the grand old flag
# when was the vietnam war broadcasted on tv
# how many hotels and casinos are in las vegas
# who were the actors in the ten commandments
# who plays sully on young and the restless
# who is buried in the hollywood forever cemetery
# where is 12 pack from i love new york from
# how did goat island nz get its name
# what are two words in spanish that are borrowed from greek
# who knows where the time goes judy collins
# who made large sums of money for the french
# how to train your dragon book why dragons are no more
# who was the man who designed so many houses after the great chicago fire
# which of the following is a reason congress uses committees
# what was the reaction of kulaks to collectivizing agriculture be specific
# what are the characters names in doc mcstuffins
# when does the hundred foot journey take place
# who sings the song you're going to love me
# what are the different types of transport in cells
# how did the barn owl get its name
# when does the new android os come out
# who played in a million ways to die in the west
# who won the war of the grand alliance
# which one of the following is a non-profit financial intermediary
# where did they find the heart of the ocean
# which is not a specifically exempted from title vii cra according to your text
# how does separation of the record keeping function from custody of assets
# when does the star movie come out in canada
# when does new episodes of good behavior come out
# what tools do floridians have to monitor current issues and the actions of public officials
# where can jah be found in the bible
# who can attend the meeting of both houses of parliament without being a member
# when does it get dark in new york december
# how many ounces in a mini bottle of liquor
# when does the new series of citizen khan start
# how do federal courts calendar and docket cases
# who is the producer of why dont we
# what is the story behind the nursery rhyme london bridge
# what state's proclamation provided a basis for the declaration of independence
# where does michigan play in the sweet sixteen
# who is not against us is for us
# what is the role of media in the canadian federal government
# what time do korean students go to school
# where am i and where am i going
# who are the poor and what are their economic characteristics
# when it is cold the cremaster muscle relaxes and the testicles are lowered away from the body
# who will be the next in line if vice mayor dies
# when is new one piece episodes coming out
# who won the gold medal in the figure skating
# where was the pirates of the caribbean filmed
# who do the los angeles rams play sunday
# what does the color federal blue look like
# what harry potter movie came out in 2008
# who were the leaders in the american revolution
# what age does high school start in australia
# what is the difference between webdings and wingdings
# who am i what am i doing here
# how long will it take me to get to portland oregon
# what was the elevation of the land where coronado crossed the rio grande
# when was a cure for bubonic plague found
# who was vice president and president without being elected by the electoral college
# when do liquor stores close on sunday in minnesota
# what were the battles of the war of 1812
# which of the following is a cluster b personality disorder in the dsm-5
# who founded each of the new england colonies
# what factors contributed to allied success in africa and italy during the second world war
# what is the difference between nagar palika and nagar nigam
# when does first quarter end in middle school
# who sings still havent found what im looking for
# which part of the graafian (tertiary) follicle is ovulated
# who built a building for love in 18th century
# when was the term black ice first used
# where is the nucleoplasm located in an animal cell
# what was a knight's job in medieval times
# which of these is a disadvantage of hydrogen fuel cells
# who founded the new york colony and why
# when did colorado become a right to work state
# which one of the following acts has become known as the federal fair housing act
# how far can you see at different heights
# how did mike and richie discover the origin of it
# what is the difference between an fbi agent and a detective
# where did they film suite life of zack and cody
# who sang put the lime in the coconut in practical magic
# which one of the following is not part of your automobile operating costs
# where does the last name joy come from
# how does our identity as a multicultural country impact on the following areas
# who does teddy end up with in grey's anatomy
# when was the first electronic cash register invented
# who says the following i like none of the gods who are worshipped at night
# what version of windows 10 is on this computer
# who is credited with founding the scholastic method
# where does the expression scott free come from
# how many matches are in a wwe live event
# who wears number 2 for the dallas cowboys
# where did the longest siege of the civil war take place
# who becomes chief of surgery after owen hunt
# who sings the best version of the first noel
# what is the quality of life like in china
# why was germany worried about the alliance between france and russia
# who discovered africa and what is the meaning of africa
# what type of aircraft does the navy fly
# what is the name of the oldest recessional moraine in the huron erie lobe
# where did the last name locklear come from
# how many mla and mp seats in telangana
# how do chemists use systems and order in their work
# which of the follow statements is true of the eastern orthodox churches
# who got their start at the comedy store
# how many double doubles does lebron james have this season
# what are the provisions of companies act 2013
# how old were jersey shore cast first season
# which of the following words have indian roots
# what is bound in heaven will be bound on earth
# how old are the cast of criminal minds
# where is the word bible written in the bible
# who played aragorn's son in return of the king
# what was life like in canada in 1867
# where does the formation of gametes take place
# which superheroes is not a member of the avengers
# when did the ottoman empire start and end
# which of the following stations has all the three gauges viz. broad metre and narrow
# who sings the 80 song stay with me
# how many goals have arsenal scored in the premier league
# who wants to be a millionaire new zealand
# where does the last name brock come from
# how many members in order of the phoenix
# who sang step by step in the 80s
# when did the modern era of college basketball begin
# what are the impacts of world war 2
# what were the main points of lucknow pact
# why did the vikings venture outside of scandinavia
# which of this following is not an activity typically performed by robots in the automotive industry
# where do you think most farming is done in the united states and why
# what does the winner of the rap game get
# where did the united states get most of the money to finance the war
# what two events lead america into the conflict what year did they enter
# what is the difference between dc and marvel characters
# where did the tom turkey get its name
# when does snow white find out emma is her daughter
# who sings the song amy what you want to do
# where was the first nfl football game ever played
# who is opening for they might be giants
# where did dry as a bone come from
# when does the sun come up in the summer
# when is this is us season 2 released on dvd
# when do we apply the mixed derivative theorem
# how did the margarita drink get its name
# which desert covers more land in south america
# who sang na na na hey hey goodbye
# where did the symbol for carbon come from
# when is the new keeping up with the kardashians airing
# why was medicare part c put into effect
# where can schedule 2 and 3 substances be sold
# how did change in the economic structure of the us promote immigration in the late 20th century
# how old was zuko when he got his scar
# who won the election of 1920 and why
# how many seasons of blindspot are on hulu
# where were all of the early english settlements located
# who sings ride with me with florida georgia line
# what kind of guns were used in the korean war
# when is the next series of the dumping ground coming out
# what are the main types of meat eaten in the uk
# when does the tv show intervention come on
# what speed is the surface current near tokyo
# who is never been the union home minister
# who has the best history in english football
# when do they find out cole is the source
# which of the following is not a function of the peer group
# how many different fast food restaurants are there in the us
# which type of currency was not used in the united states during its early years answers.com
# what is the meaning of peter piper picked a peck of pickled peppers
# who said you shall not press down upon the brow of labor this crown of thorns
# when is season 3 of el vato coming out
# who is the woman in the mask got
# what are the sacraments in the lutheran church
# who was pocahontas husband in the disney movie
# what were key resources exploited by colonial settlers in new england
# when is a touchdown scored in flag football
# when did police in uk stop carrying guns
# who migrated to the sahara savanna in present-day southeastern nigeria
# when will the holy door be opened again
# where was the 1998 movie wild things filmed
# which of the following countries of southwest asia and north africa has the most diversified economy
# where was the cotton gin invented and where is it used today
# which of the following is another name for a tropical rainforest
# where do you go to my lovely full version
# what is the name for the theory that says that public opinion drives the political machine
# who played the drummer in school of rock
# where did the expression with a grain of salt come from
# why is it important to know the discharge of a river
# when does ross live in monica's apartment
# where is pineapple express supposed to take place
# who made the laws in the shang dynasty
# what is the name of the goddess of the moon
# when does jane find out who her father is
# what made the glider to move over the air track device
# when will the curse be broken in once upon a time season 7
# how did the economic role of women change during the civil war
# where do the arizona cardinals play this week
# what is the golden door in the new colossus
# where is the aoss button on the ps4
# who has man city lost against this season
# what is the difference between hastings essential and hastings direct
# which civilizations had advanced writing and technology in present day mexico
# when was the sir robert bond bridge built
# what does the greek word onta mean in english
# what did the us do after soviets launched sputnik
# how many campaign mission in call of duty ww2
# when did mulder and scully have a kid
# who is the new agent on criminal minds
# who said those who live in glass houses
# what kind of food do you eat on christmas
# what is the benefit to an organism in biochemically transforming citrate
# who is the man in the high tower
# what month has the most rain in florida
# which of the following does not have a table in the dresden codex
# where will the all star game be played
# what type of volcano is one tree hill
# when is made in chelsea available on 4od
# who sings the song loving you is easy
# where does how to make an american quilt take place
# who owns the one ring in real life
# who plays the crazy lady on days of our lives
# where do most of the worlds living things live
# where is the acc championship game being played tonight
# who makes the most money in a film
# how many years is a life sentence in delaware
# what is a good number of inventory turns
# what does negan mean in the walking dead
# how many seats are there in indigo flight
# how many electron pairs are in the outer shell of nitrogen
# who were the notable filipino sociologist who help in the propagation of the course
# what happens in a mixture (write two sentences that state what happens in a mixture.)
# who do the patriots play on november 5
# what is the perfect height for a model
# when does new season of star trek discovery start
# when did the nfl teams join the league
# who works in a museum or wildlife in a zoo aquarium and nature center
# what type of cell doesnt have a cell wall
# where did the carbon dioxide come from in the interactive
# what country is south of the united states
# who said it's a jungle out there
# when do they blow the shofar on the feast of trumpets
# when does mlb resume after all star break
# where would you go if freedom of speech is denied to you
# what is the significance of jumping over a broom at a wedding
# when is it going to snow in florida again
# which city had the highest number of english and hindi newspapers in 2012 and 2013
# when measuring a pulse which of the following is not one of the three important characteristics
# where does brown fall on the color wheel
# who sold new hampshire to the king of england
# what is the meaning of source for historians
# who authored both on architecture and on painting the first renaissance text on art theory
# who maintained law and order throughout japan and negotiated peace
# who is the guy that does the capital one commercial
# who were the jesuits and what role did they play in the new world in the 16th and 17th centuries
# what is the difference between italian beef and french dip
# what are the goals of the us chamber of commerce
# what did the pretty little liars do to sarah
# what is the primary subsistence crop in latin america
# when is ori and the will of the wisps coming out
# where does the saying kick the bucket come from
# how did arts change as a result of the enlightenment
# where do you go when the stars go blue
# what happened to claire on days of our lives
# how hot are coals in a wood fire
# what jobs can you get with a police caution
# where did the phrase not my first rodeo come from
# how did the estates general illustrate the inequality of the french government
# how many crackers can you eat in 1 minute
# when do annie and liam start hanging out
# where has gold been found in the united states
# what are the airlines in the united states
# what is meant by manram during sangam age
# when is project mc2 part 7 coming out
# which of the following statements regarding the dual court system in the united states is true
# where is the seven deadly sins found in the bible
# who played the mother in the glass castle
# which of the following is the biggest threat to the survival of local cultures and traditions today
# what is the name of god of love
# who benefited from the industrial revolution in britain
# when does the rocket league championship series start
# what was the most pressing issue facing america at the dawn of the 20th century
# who gained fame for her actions during the american civil war
# what is the largest biome in south africa
# ...
# who is argentina playing in the world cup
# when was australia ruled by the british empire
# what happened to toby in season 7 the office
# where is prokaryotic life found around hydrothermal vents
# where did the last name bias come from
# who is lost to the expedition while they are in drepanum
# where does the heel toe polka come from
# who is the girl in the it crowd
# where does the phrase bee line come from
# where does ba fly to in new zealand
# when did the university of pennsylvania go coed
# who did tony booth play in coronation street
# when do england play cricket in the west indies
# what is the difference between sony xbr and kdl
# who dies in the movie truth or dare
# when does the second fallen movie come out
# what happened to lt dan in forrest gump
# what aspect of ancient greece has had the greatest influence on the world
# who published alexander and the terrible horrible no good very bad day
# where is im a celebrity get me outta here filmed
# how old was hercules in the disney movie
# where are the dairies that make bluebell ice cream
# when does the first one piece movie take place
# where do we see wave-cut platforms on oahu
# what is the name of the theater where rocky likes to take ruth
# how many songs can windows media player handle
# what was the bloodiest period in the french revolution
# what part of speech is created when this suffix is added to a word ward
# when does the leeds festival lineup get announced
# who is main character in game of thrones
# what system does the sec require companies to use when preparing financial statements
# who are the actors in god is not dead
# who pkays rebeccas mother on this is us
# where was how to lose a guy in 10 days filmed
# who did dallas cowboys beat in the super bowl
# what is the difference between coleman fuel and unleaded gas
# when was the first time the philadelphia eagles went to the superbowl
# who rejected secret service protection after his election
# when did the salvation army come to australia
# when was the hanging gardens of babylon completed
# why must one value in every table be unique
# who swore in the new deputy prime minister of australia
# which of the following major cultural divisions runs through the former yugoslavia
# who are the characters in the black cat
# what is an acceptable three letter abbreviation for phenylthiocarbamide
# how old is mr feeny from boy meets world
# which of the following is not an example of the rna processing that occurs in eukaryotes
# who played the doctor in band of brothers
# who used to be on good morning america
# where is the world series being held at this year
# when does stefan turn his humanity back on in season 8
# what is the stock symbol for mars candy
# what were two consequences of the french colonization of haiti
# when do other cultures celebrate the new year
# which of the following was not one of the roman senates powers in the early days
# why did european countries give up their colonies in southeast asia
# what does the song i built a friend mean
# when was english ivy introduced to the us
# when was the last time easter was on april 17
# who has become the first woman chairman of indian bank association
# which statement provides the most accurate description of u.s foreign policy in the 1800s
# who was considered one of the greatest sailors during the history of early china
# how far is skipper's virginia from here
# what is the next comet to pass earth
# what kind of vw jetta do i have
# when do sandhill cranes lay eggs in florida
# when was the first cell phone call made
# where does the tv show bellvue take place
# how old is rainbow dash in my little pony
# how many roles did an actor have in a play
# where are the blueprints for creating a person stored and communication
# what government structure did the aztec and inca have in common
# who had a cousin who was a strong supporter for independence
# who was the crackhead in menace to society
# who were the first disciples to be called
# who proposed 30 different suggestions for why crime remained high in some areas
# where was the song cheeseburger in paradise written
# who argued that as a philosopher he was committed to radical skepticism
# where do you you go to my lovely
# where does the last name arvizu come from
# which of the following is not one of the primary considerations when designing the user interface
# what resources did the british empire get from india
# when does season 2 of death note start
# when was the first accurate world map made
# where does the last name almond come from
# why was there a civil war in cambodia
# what is the meaning of kumkum in english
# who were the humanists and what did they attempt to do
# when does knocking on heavens door take place
# what led to a decline in great zimbabwe (5 points)
# who plays tim allen's wife in the santa clause
# who were some of the delegates to the constitutional convention of 1787
# what was colombia like in the 1980s and 1990s
# who did develop the abandonment stage in the plc
# where does one punch man get his power
# who fights the hound in game of thrones
# who sings i always feel like somebodys watching me
# what movies does ll cool j die in
# when was the microphone first used in music
# where does the snake live in the gruffalo
# why is there a black baby on this is us
# how long did it take to travel in ancient rome
# who is the author of ranger in time
# which of the following is not a characteristic of the core regions
# what is the significance of the mandala motif in the solid mandala
# what do the lyrics from stairway to heaven mean
# which of the following is an action of the latissimus dorsi muscle
# what led to european exploration of the americas
# when does mulder find out scully is pregnant
# how many units in century village pembroke pines
# which of the following was not a part of minstrelsy
# how much power does a wind mill produce
# where do they sell wonka bars in the uk
# when did best before dates start in the uk
# which state has largest number of towns in india
# how long has michigan had no fault insurance
# what are the four capital cities on islands in canada
# what forces businesses industries and governments to make decisions
# which is the largest religious gathering in the world
# where was the landscape with the fall of icarus painted
# what is the national geographic channel on spectrum
# which of the following is (are) in violation of the equal credit opportunity act
# how many rides are in disneyland and california adventure
# what does the symbol of the virgin mary mean
# how did they make wine in bible times
# who plays clare on days of our lives
# how many players are on an nhl team
# when does copyright start do i have to register the work with the government
# where does the wedding take place in the devil's arithmetic
# where are they now cast of drop dead diva
# how many blocks does hassan whiteside have in his career
# which was a change made under the meji government in japan
# what does a tennessee license plate look like
# which city was acquired by the usa through the gadsden purchase
# what does the cytoplasm do for the animal cell
# who played danny's brother in law on blue bloods
# where do condensation reactions occur in the body
# how many copies of holes have been sold
# where do the chargers and rams play football
# what are the president's duties as stated in the constitution
# who is said to have been with boxer when he was on his deathbed
# why are there no new episodes of young sheldon
# how to explain the genre of a book
# what are the four countries with a higher spanish-speaking population than the u.s
# why are there so many spider webs in the trees
# what happened to berlin's daughter on the blacklist
# who won the first aaad beauty pageant contest
# when do new episodes of boruto come out
# what causes changes of state in a system
# when was the draft of the national assembly constitution completed what was its main objective
# which is not characteristic of a process based structure
# who played rocky's son in the rocky movies
# which of the following is a part of the insertion of the flexor digitorum profundus
# who sings the best version of we wish you a merry christmas
# where was the 9th life of louis drax filmed
# when did they stop using mercury in thermometers
# which glass slipper did cinderella leave behind at the ball
# when is galactik football season 4 coming out
# what do we call the eighteenth century thinkers who believed that wisdom
# which of the following is not a constitutional requirement to become president of the united states
# when did horse drawn carriages stop being used in london
# who did jeremy dyson play in league of gentlemen
# who plays the arch bishop on blue bloods
# when do amy and ricky sleep together for the second time
# what does the table show about how congress voted for the civil rights act of 1957
# where have you been where are you going short story
# who were the west area human computers and why did they do this work
# how much does a 4 star general in the marine corps make
# what is the mean of pkc in hindi
# what dog breeds are born without a tail
# when do dan and serena get back together in season 3
# which of the following is true of the first congress
# which of the following is not one of the six common air pollutants
# where did the expression great scott come from
# when was the last time the packers were shut out twice in a season
# where is cotton dyed and made into fabric and sewn into clothing
# which of the following is known as the westminster model
# who published an article suggesting current species were descended from other species
# what happened to the mom on petticoat junction
# when do mark and lexie die in grey's anatomy
# what is difference between rotameter and flow meter
# who is the highest official elected in saudi arabia today
# where was harold & kumar go to white castle filmed
# where was the film ice cold in alex filmed
# how much does blue planet cost to make
# what do greek say when they break plates
# what impact did the great migration have on american society
# what love got to do with it bucks fizz
# when did the first steamboat come to texas
# who have been the super bowl halftime performers
# who played scarlett's sisters in gone with the wind
# how i met your mother ducky tie cast
# why are stop signs in italy in english
# when was the last time we were at defcon 4
# how many chapters are in spec ops the line
# how long is an episode of cowboy bebop
# who among the following is the author of ramayana
# who did ash give a kidney to on home and away
# which indian state shares its boundary with the most number of states or union territories
# who played drums on pick up the pieces
# when does the talk new season start 2017
# who sang the theme song to the brady bunch
# when it came to mind that i didn't care
# how does avant garde film differ from classic hollywood cinema
# what two crops are puerto ricos leading exports
# how many seasons of the strain on hulu
# where does the last name foy come from
# when did smoking get banned in public places
# what were the types of government in the new england colonies
# who won the wwe mixed match challenge tonight
# who said political science is the science of power
# who won between the cowboys and the chargers
# where did they film love at the shore hallmark
# when did jeep wrangler go to fuel injection
# who is included in the electoral college for the election of the president
# when does the first fairy tail movie take place
# when does glitch season 3 come out on netflix
# what radio station is the st louis cardinals game on today
# who directed government policy during harding and coolidge
# when does rick grimes die in the comic book
# what has holmes been doing while watson is at his club
# who is representing ireland in the winter olympics
# where did the story a day in the country happened
# when did the calendar change from 360 days to 365 days
# what were the 3 major native american civilizations in north america
# which of the following areas did not have a history of serious colonial conflicts after world war ii
# what is the legal age for a job
# when was the last time costa rica had a hurricane
# who plays alex's dad on grey's anatomy
# what kind of clothes did the maya wear
# what did australia provide for the british empire
# who was the oldest man ever to have been appointed chief justice
# what does it mean when find my iphone is off
# who is generally regarded as the father of american psychology
# who had participated in telangana movement during 2009
# how many games did elise stacy play for the hockeyroos
# when a cork is added to a glass of water
# how many recursive calls can a recursive method have
# who said the only thing certain in life is death and taxes
# which of these is not an external force that affects business cycles
# what song does sam sing in ted 2
# who is the highest paid footballer of all time
# when does the movie wonder come out in the uk
# when individuals buy a computer program they buy a license to
# why were european countries interested in west africa and north africa
# where did the concept of time zones come from during this time period
# how long did it take for the yosemite bill to pass
# which of the following is the insertion of the latissimus dorsi muscle
# where is blood connective tissue found in the body
# how are the suburbs of paris different than those of most canadian cities
# how to tell the age of a loggerhead turtle
# where can i buy a japanese dwarf flying squirrel
# what is the song season in the sun about
# why do we have a number of courts in australia
# where does the last name roman come from
# which of the following is guaranteed by the u.s. constitution
# what are nox and where do they come from
# what is the shape of a house called
# where was i am not your negro filmed
# what is the difference between a bernese mountain dog and a swiss mountain dog
# how many players on a premier league team
# who saw culture as a means to an end rather than an end it itself
# how did latin america gain independence from spain
# what is the unique property of an arrowhead
# what did the cast of stranger things make
# which of the following would increase the level of planned real​ investment
# who were the pilots who dropped the atomic bombs
# who are the oldest coaches in the nfl
# when does mcdonald's monopoly start 2018 usa
# how many hoarders are there in the us
# where do you go to peter sarstedt lyrics
# how much greater is the average temperature on earth than the average temperature on jupiter
# why did the panic of 1837 in the united states have an effect on texas
# how many sets of petals does a tudor rose have
# what does mexico need to qualify for world cup
# what were the buildings made out of in towns in elizabethan england
# where was the first school shooting in kentucky
# who inducted chicago into the hall of fame
# where have you been all my life the beatles
# what two events caused the u.s. to be neutral at the start of wwii
# which country is known as land of seven seas
# which of the following is not an example of isolated missing detained or captured imdc personnel
# when does star wars rebels season 4 episode 16 come out
# when did belfast become part of the uk
# what is the spanish name for santa clause
# when does law and order criminal intent come on
# who does not have an extradition treaty with canada
# what type of houses did the pequot live in
# who sang time keeps on slipping into the future
# who propounded the concept of cross elasticity of demand
# who was the guy who said the british are coming
# what is the best alternative energy source to replace fossil fuels
# what did dee loc steal in the wash
# when did tom brady start playing football as a kid
# where did the saying send it down huey come from
# who gives a damn about an oxford comma
# where does the last name lundy come from
# which of the following statement is true in a nondeterministic halting tm m
# when did the states secede during the civil war
# when do cristina and meredith make up season 5
# why is this hash function perfect by definition but imperfect in practice if implemented in c
# which of the following results from stimulation by the parasympathetic nervous system
# what is a 5 5 4 shift rotation
# which of the following is not a provision of the sarbanes-oxley act (sox)
# which of the following factors is not affecting the sv

# %%
pos = nlp("mary's wanting to go out was invalid")
for i in pos:
    print("%s | POS: %s | Head: %s | Subtree: %s" % (i, i.tag_, i.head, list(i.subtree)))
#     if i.tag_ == 'POS':
#         h = i.head
#         m = list(h.head.subtree)
#         tags = [t.tag_ for t in m]
#         print(m[:tags.index('POS')], m[tags.index('POS') + 1: ])
# Out:
# mary | POS: NNP | Head: wanting | Subtree: [mary]
# 's | POS: POS | Head: wanting | Subtree: ['s]
# wanting | POS: VBG | Head: was | Subtree: [mary, 's, wanting, to, go, out]
# to | POS: TO | Head: go | Subtree: [to]
# go | POS: VB | Head: wanting | Subtree: [to, go, out]
# out | POS: RP | Head: go | Subtree: [out]
# was | POS: VBD | Head: was | Subtree: [mary, 's, wanting, to, go, out, was, invalid]
# invalid | POS: JJ | Head: was | Subtree: [invalid]

# %%
from spacy import displacy


displacy.serve(nlp("where do harry potter’s aunt and uncle live"), style="dep")
# Out:
# /Users/nehasrikanth/opt/anaconda3/envs/dnli/lib/python3.8/site-packages/spacy/displacy/__init__.py:97: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="80bb8f3d67e443119906566c40fe6e91-0" class="displacy" width="1625" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">when</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">did</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">nfl</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">start</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">playing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">national</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">anthem</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-80bb8f3d67e443119906566c40fe6e91-0-0" stroke-width="2px" d="M70,352.0 C70,2.0 750.0,2.0 750.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-80bb8f3d67e443119906566c40fe6e91-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-80bb8f3d67e443119906566c40fe6e91-0-1" stroke-width="2px" d="M245,352.0 C245,89.5 745.0,89.5 745.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-80bb8f3d67e443119906566c40fe6e91-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-80bb8f3d67e443119906566c40fe6e91-0-2" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-80bb8f3d67e443119906566c40fe6e91-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-80bb8f3d67e443119906566c40fe6e91-0-3" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-80bb8f3d67e443119906566c40fe6e91-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-80bb8f3d67e443119906566c40fe6e91-0-4" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-80bb8f3d67e443119906566c40fe6e91-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M910.0,354.0 L918.0,342.0 902.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-80bb8f3d67e443119906566c40fe6e91-0-5" stroke-width="2px" d="M1120,352.0 C1120,177.0 1440.0,177.0 1440.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-80bb8f3d67e443119906566c40fe6e91-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,354.0 L1112,342.0 1128,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-80bb8f3d67e443119906566c40fe6e91-0-6" stroke-width="2px" d="M1295,352.0 C1295,264.5 1435.0,264.5 1435.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-80bb8f3d67e443119906566c40fe6e91-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,354.0 L1287,342.0 1303,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-80bb8f3d67e443119906566c40fe6e91-0-7" stroke-width="2px" d="M945,352.0 C945,89.5 1445.0,89.5 1445.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-80bb8f3d67e443119906566c40fe6e91-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1445.0,354.0 L1453.0,342.0 1437.0,342.0" fill="currentColor"/>
# </g>
# </svg>
# </figure>
# </body>
# </html></span>
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /var/folders/7t/dq_q5_d944xbjbfpzcdd2p1w0000gn/T/ipykernel_80022/2592351186.py in <module>
#       2
#       3
# ----> 4 displacy.serve(nlp("when did the nfl start playing the national anthem"), style="dep")
#
# ~/opt/anaconda3/envs/dnli/lib/python3.8/site-packages/spacy/displacy/__init__.py in serve(docs, style, page, minify, options, manual, port, host)
#      97         warnings.warn(Warnings.W011)
#      98     render(docs, style=style, page=page, minify=minify, options=options, manual=manual)
# ---> 99     httpd = simple_server.make_server(host, port, app)
#     100     print(f"\nUsing the '{style}' visualizer")
#     101     print(f"Serving on http://{host}:{port} ...\n")
#
# ~/opt/anaconda3/envs/dnli/lib/python3.8/wsgiref/simple_server.py in make_server(host, port, app, server_class, handler_class)
#     152 ):
#     153     """Create a new WSGI server listening on `host` and `port` for `app`"""
# --> 154     server = server_class((host, port), handler_class)
#     155     server.set_app(app)
#     156     return server
#
# ~/opt/anaconda3/envs/dnli/lib/python3.8/socketserver.py in __init__(self, server_address, RequestHandlerClass, bind_and_activate)
#     450         if bind_and_activate:
#     451             try:
# --> 452                 self.server_bind()
#     453                 self.server_activate()
#     454             except:
#
# ~/opt/anaconda3/envs/dnli/lib/python3.8/wsgiref/simple_server.py in server_bind(self)
#      48     def server_bind(self):
#      49         """Override server_bind to store the server name."""
# ---> 50         HTTPServer.server_bind(self)
#      51         self.setup_environ()
#      52
#
# ~/opt/anaconda3/envs/dnli/lib/python3.8/http/server.py in server_bind(self)
#     136     def server_bind(self):
#     137         """Override server_bind to store the server name."""
# --> 138         socketserver.TCPServer.server_bind(self)
#     139         host, port = self.server_address[:2]
#     140         self.server_name = socket.getfqdn(host)
#
# ~/opt/anaconda3/envs/dnli/lib/python3.8/socketserver.py in server_bind(self)
#     464         if self.allow_reuse_address:
#     465             self.socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# --> 466         self.socket.bind(self.server_address)
#     467         self.server_address = self.socket.getsockname()
#     468
#
# OSError: [Errno 48] Address already in use

# %%
s = "it was rupak that ate the cookies"

# %%
import numpy as np

# %%
s1 = "it was neha that ate the cookies"

# %%
check_cleft(nlp(s1))

# %%
tokens = list(nlp(s1))
#print(tokens)
tokens_str = [str(token) for token in tokens]
#print(tokens_str)
cleft_word = np.intersect1d(tokens_str, ["it"])
#print(cleft_word)
index = tokens_str.index(cleft_word)

cop = tokens[index + 1]
obj = None 
for child in cop.children: 
    #print(child, child.dep_ )
    
    if child.dep_ in ['attr', 'dobj']: 
        obj = child
        break

# %%
list(obj.children)

# %%
check_cleft(nlp(s1) )

# %%
comp_sent = "Clifford is a bigger dog than Cujo."  # should evaluate to true

# %%
# test sentences
comp_sent = "Is Clifford a bigger dog than Cujo?"  # should evaluate to true
comp_sent2 = "Clifford is a more giant dog than Cujo."  # should evaluate to true
non_comp_sent = "Clifford is a bigger dog than I thought,"  # should evaluate to false
other_comp = "Clifford is bigger of a dog than Cujo."  # should evaluate to true
other_comp2 = "Clifford is bigger a dog than Cujo."  # should evaluate to true, currently doesn't

# displacy.serve(nlp(other_comp2),style='dep')

# %%
check_comparative(nlp(comp_sent))

# %%
check_sentence_for_embedded_question(nlp("I fail to see how you can rationalize rewarding illegality."))

# %%
s10 = "a microsecond later, images from his exterior sensors didn't snap into focus"

find_change_of_state(nlp(s10))

# %%
s9 = "Lisa stopped petting Tom's cat"

q = "both kids smiled"
q1 = "all three cat owners that julia spoke to want another cat"
q2 = "both of our fathers were thin"

# %%
q3 = "do you see any problem at all because folks on both sides of the aisle have tremendous respect from him?"

# %%
s4 = "meaning behind the song whiter shade of pale"

# %%
find_change_of_state(nlp(s9))

# %%
find_continuation_of_state(nlp(s9))

# %%
def find_numeric_determiners(sentence):

    numeric_predeterminers = set(["all"])
    special_determiners = set(["both"])
    all_determiners = numeric_predeterminers | special_determiners


    # extract words as list of strings
    words = [t.text.lower() for t in sentence]
    
    #print(words)
    if set(words) & all_determiners:
        for token in sentence:
            include = False
            if token.text.lower() in special_determiners:
                if token.tag_ == "DT" and token.dep_ == "det":
                    include = True
                    return True  
                    
                if not include:
                    for child in token.children:
                        if child.dep_ == "prep" and child.text.lower() == "of":
                            include = True
                            return True 


            if not include and token.text.lower() in numeric_predeterminers:
                        
                if token.tag_ == "DT" and token.dep_ == "det":
                    head_token = token.head

                    if head_token.tag_ == "CD":
                        include = True # all three of the children
                        return True  
                        
                    else :
                        
                        for child in head_token.children:
                            ##print("\t", child, child.dep_, child.tag_)
                            if child.tag_ == "CD" and child.dep_ == "nummod":  ## changed token.dep_ to child.dep_ 
                                #print("here")
                                ##print(sentence)
                                include = True # all three children
                                #print(include)
                                return True 
                
                elif token.tag_ == "DT":
                    for child in token.children:
                        if child.dep_ == "prep" and child.text.lower() == "of":
                            for child_child in child.children:
                                if child_child.dep_ == "pobj":
                                    has_det = False
                                    has_nummod = False
                                    for child_child_child in child_child.children:
                                        if (child_child_child.tag_ == "CD"
                                            and child_child_child.dep_ == "nummod"):
                                            has_nummod = True # all of the three children
                                        if (child_child_child.tag_ == "DT"
                                            and child_child_child.dep_ == "det"):
                                            has_det = True # all of the three children

                                    include = has_det and has_nummod
                                    if include:
                                        #print(sentence)
                                        return True 
                            if include:
                                return True 


    return False

# %%
find_numeric_determiners(nlp("all three deny the allegation."))
# Out:
# True

# %%
s5 = "both channels is administered by the u.s. department of justice"

# %%
from re_verbs_better import find_re_verbs

# %%
re_verbs_corpus = "wordlists/re_verbs_updated.txt"

def find_re_verbs(sentence, cos_predicate_path = re_verbs_corpus):

    with open(cos_predicate_path, 'r') as f:
        re_verbs = set([l.strip() for l in f.readlines()])

    # extract words as list of strings
    words = [t.text for t in sentence]
    
    if set(words) & re_verbs:
        
        for token in sentence:
            #print(token, token.tag_, token.dep_)
            if (str(token) in re_verbs
                and token.tag_[0] == "V"
                and token.dep_ == "ROOT"):  # why?? 
                
                if len(list(token.children))  > 0: 
                    return True 
                    
    return False

# %%
s6 = "holly decided to reconnect the charger?"

# %%
find_re_verbs(nlp(s6))
# Out:
# False

# %%
with open(re_verbs_corpus, 'r') as f:
        re_verbs = set([l.strip() for l in f.readlines()])

# %%
"reenter" in re_verbs
# Out:
# False

# %%
from re_verbs_better import find_re_verbs

# %%
from spacy import displacy
from spacy.matcher import PhraseMatcher

implicative_path = "wordlists/implicative_predicates.txt"

def find_implicatives(sentence, impl_pred_path=implicative_path):
    
    nlp = spacy.load("en_core_web_sm")
    matcher = PhraseMatcher(nlp.vocab)
    
    with open(impl_pred_path, 'r') as f:
        implicatives = [l.strip() for l in f]
        implicative_pairs = [item.split(":") for item in implicatives] #seperate predicates and inferences
        implicative_predicates = [pair[0] for pair in implicative_pairs]
        implicative_inferences_dict = {pair[0]:pair[1] for pair in implicative_pairs} #dictionary mapping predicates to inferences
        implicative_verbs = set([p.split()[0] for p in implicative_predicates])
        # add implicative predicates to matcher
        patterns = [nlp.make_doc(text) for text in implicative_predicates]
        matcher.add("IMPL_PRED_LIST", None, *patterns)
        

    #words = [t.text for t in sentence]
    # find matches of implicative predicates in the sentence
    matches = matcher(sentence)

    if len(matches) > 0:
        for match_id, start, end in matches:
            impl_phrase = sentence[start:end]
            #print(str(impl_phrase))
        # match found, proceed to further checking
        for token in sentence:
            if (str(token) in implicative_verbs
                and token.tag_[0] == "V"
                and token.dep_ == "ROOT"):
                #include = False
                for child in token.children:
                    if child.dep_ == "prep":
                        for childs in child.children:
                            if childs.dep_ == "pcomp" and childs.pos_ == "VERB":
                                return True 
                                #include = True
                                #break
                    else:
                        if child.dep_ == "xcomp" and child.pos_ == "VERB":
                            return True 
                            #include = True
                            #break
    return False

# %%
s = "survivors managed to scramble out through the tiny gap in the rocks"
s1 = "survivors scrambled through the tiny gaps on the rocks"

# %%
from implicative_verbs_better import find_implicatives

# %%
temporal_prepositions = ['before', 'after', 'while', 'since', 'because']
accepted_head_tags = {
    'VBG': 'gerund',
    'VBN': 'past-participle',
    'VBD': 'past',
    'VBP': 'non-3sg-present',
    'VBZ': '3sg-present',
    'VB': 'base',
}

def find_temporal_adverbs(sentence):
    words = [t.text for t in sentence]
    preps_in_sentence = [word for word in sentence if word.lemma_ in temporal_prepositions]
    print(preps_in_sentence)
    if len(preps_in_sentence) > 0:
        for prep in preps_in_sentence:
            prep_children = [child for child in prep.children]
            # get the tag(s) of the immediate child
            prep_tags = [child.tag_ for child in prep_children]
            # check if tag is accepted (must be a verbal category)
            accepted_prep_tags = list(set(prep_tags) & set(accepted_head_tags.keys()))
            if len(prep_children) > 0 and len(accepted_prep_tags) > 0:
                trigger_specific_fields = {
                    "preposition": prep.text,
                    "embedded_clause_head_tag": prep_tags,
                }
                return trigger_specific_fields
    return None

# %%
find_temporal_adverbs(
    nlp("he took them to the NL Championship Series last year before being swept by the Atlanta Braves.")
)
# Out:
# [before]
# {'preposition': 'before', 'embedded_clause_head_tag': ['VBN']}

# %%
check_sentence_for_embedded_question(nlp("Who is the current monarch of France?"))
# Out:
# (False, None, None)

# %%
check_sentence_for_embedded_question(nlp("who played scotty in the new star trek movie"))
# Out:
# (False, None, None)

# %%
from glob import glob

# %%
csvs = glob("annotation/round2/*")

# %%
import pandas as pd
PRESUPPOSITIONAL_WH_WORDS = ["why", "how", "where", "when", "who", "what", "which"]

# %%
import nump

# %%
for file in csvs: 
    df = pd.read_csv(file)
    for index, row in df.iterrows(): 
        beginning_token = row['sentence'].lower().split()[0]
        if beginning_token in PRESUPPOSITIONAL_WH_WORDS and not pd.isnull(row['presupposition']): 
            print(row['trigger'], '|', row['sentence'], '|', row['presupposition'], '|', row['trigger_data'],  "\n")
# Out:
# comparatives | When it comes to mental toughness , there is no better team than this one . | this one is a team with mental toughness. | {'adjective': 'better', 'noun': 'team'}
#
# re_verbs | When AngloGold extracts the last ounces of gold from the mountain it has destroyed to make money , geophysical forces will recreate it , shoving more rocks to the surface . | The mountain was created once before | {'predicate': 'recreate'}
#
# continuation_of_state | How soon after the visit to ABC News did the child begin to show some symptoms , and what were the symptoms exactly ? | The child didn't show any symptoms before the visit to ABC News. | {'predicate': 'begin'}
#
# factives | What he 's doing is totally and completely normal : He 's discovering his body , and discovering that rubbing his penis feels good . | Rubbing his penis feels good. | {'factive': 'discovering', 'embedded_clause': "What he 's doing is totally and completely normal"}
#
# change_of_state | When she 'd settled her cousin in the stillroom , Constance returned to Mill Hall . | Constance was previously at Mill Hall. | {'predicate': 'returned'}
#
# clefts | When these biological systems start to collapse , it 's not something that will show up on the news . | Something will show up on the news. | {}
#
# embedded_question | Which means , throw something up and you know exactly where it will fall to moon again . | The thing you throw will fall to moon again somewhere. | {'predicate': 'know', 'embedded_question': 'exactly where it will fall to moon again'}
#
# clefts | When a child is sick , more often than not it 's the mother who takes off work to stay home , or comes home from work when she gets the call from school that her little one has just puked in the trash can or fallen off the play structure and broken her arm . | Someone takes off work to stay home , when a child is sick, or comes home from work when the call comes from school that the little one has just puked in the trash can or fallen off the play structure and broken her arm . | {}
#
# embedded_question | When you see what 's happening on the streets of America and streets of Europe , whether it 's -- whether the terrorist 's acts are fomented by domestic terrorists unrelated to do ISIL , or whether it 's ISIL inspired , people are worried about safety in their own community . | Something is happening on the streets of America and the streets of Europe. | {'predicate': 'see', 'embedded_question': "what 's happening on the streets of America and streets of Europe"}
#
# temporal_adverbs | When building , it also helps if you drill all of the pivot holes dead center in each 2-by-4 before gluing and nailing on the plywood . | You are supposed to glue and nail on the plywood. | {'preposition': 'before', 'embedded_clause_head_tag': ['VBG']}
#
# temporal_adverbs | When the women 's catch rate begins to decline , Aluta 's aunt suggests they take a break before moving to the next pond . | They will move to the next pond. | {'preposition': 'before', 'embedded_clause_head_tag': ['VBG']}

# %%
x = nlp("Which means , throw something up and you know exactly where it will fall to moon again.")

# %%
check_sentence_for_embedded_question(x)
# Out:
# (True, know, 'exactly where it will fall to moon again')

# %%
??check_sentence_for_embedded_question

# %%
for file in csvs: 
    df = pd.read_csv(file)
    for index, row in df.iterrows(): 
        beginning_token = row['sentence'].lower().split()[0]
        if beginning_token in PRESUPPOSITIONAL_WH_WORDS and row['sentence'][-1] == '?': 
            print(row['trigger'], '|', row['sentence'], '|', row['presupposition'], '|', row['trigger_data'],  "\n")
# Out:
# implicative_predicates | Why , then , would anyone bother to try to expand the genetic alphabet ? | nan | {'predicate': 'bother', 'inference': 'the action requires small effforts'}
#
# factives | How can you tell whether you 're paying a fair price or getting what you 're paying for ? | nan | {'factive': 'tell', 'embedded_clause': "whether you 're paying a fair price or getting what you 're paying for"}
#
# change_of_state | Who could stay underwater like Toci , when bearded CaUigarichichichich attempted to drown him with ten , twenty dunkings , one after the other ? | nan | {'predicate': 'stay'}
#
# continuation_of_state | How soon after the visit to ABC News did the child begin to show some symptoms , and what were the symptoms exactly ? | The child didn't show any symptoms before the visit to ABC News. | {'predicate': 'begin'}
#
# implicative_predicates | How has he managed to rise so high while maintaining the passion and commitment that distinguished him as chairman of the Student Nonviolent Coordinating Committee ? | nan | {'predicate': 'managed to', 'inference': 'the action takes effort'}
#
# re_verbs | Why should n't he have remarried ? | nan | {'predicate': 'remarried'}
#
# embedded_question | How would she recognize what the pills were ? | nan | {'predicate': 'recognize', 'embedded_question': 'what the pills were'}
#
# factives | Who would have known it would change his life ? | nan | {'factive': 'known', 'embedded_clause': 'it would change his life'}
#
# implicative_predicates | Why do we have to teach students to neglect good practice , real practice , just for that ? | nan | {'predicate': 'neglect', 'inference': 'the failure (if any) of the action is due to carelessness'}
#
# numeric_determiners | Why should Iran 's radical regime change for the better when it can enjoy the best of both world 's : aggression abroad , prosperity at home ? | nan | {'predicate': 'both'}
#
# temporal_adverbs | Why would anybody want to come to work at a place before meeting those people ? | nan | {'preposition': 'before', 'embedded_clause_head_tag': ['VBG']}
#
# temporal_adverbs | What is the one bill you wished you had proposed but did n't while in the Senate ? | nan | {'preposition': 'while', 'embedded_clause_head_tag': ['VBD', 'RB', 'IN']}
#
# factives | What do you mean you want a chair ? | nan | {'factive': 'mean', 'embedded_clause': 'you want a chair'}
#
# implicative_predicates | How did they manage to dig a hole ? | nan | {'predicate': 'manage to', 'inference': 'the action takes effort'}
#
# re_verbs | Why did we reunite at the Fifth Congress , again acting correctly , then at the Sixth Congress again go our separate ways , yet again correctly ? | nan | {'predicate': 'reunite'}

# %%
for i in nlp("which philosopher advocated the idea of return to nature"):
    print(i, i.tag_, i.head)
# Out:
# how WRB orchestra
# did VBD orchestra
# orchestra VB orchestra
# change NN orchestra
# in IN change
# the DT period
# romantic JJ period
# period NN in

# %%
displacy.serve( nlp("which philosopher advocated the idea of return to nature"))
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="90fdc7aa9cfd421ab57dc88c560121b5-0" class="displacy" width="1625" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">which</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">philosopher</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">advocated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">idea</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">return</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">nature</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-90fdc7aa9cfd421ab57dc88c560121b5-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-90fdc7aa9cfd421ab57dc88c560121b5-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-90fdc7aa9cfd421ab57dc88c560121b5-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-90fdc7aa9cfd421ab57dc88c560121b5-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-90fdc7aa9cfd421ab57dc88c560121b5-0-2" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-90fdc7aa9cfd421ab57dc88c560121b5-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,179.0 L587,167.0 603,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-90fdc7aa9cfd421ab57dc88c560121b5-0-3" stroke-width="2px" d="M420,177.0 C420,2.0 750.0,2.0 750.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-90fdc7aa9cfd421ab57dc88c560121b5-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,179.0 L758.0,167.0 742.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-90fdc7aa9cfd421ab57dc88c560121b5-0-4" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-90fdc7aa9cfd421ab57dc88c560121b5-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,179.0 L928.0,167.0 912.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-90fdc7aa9cfd421ab57dc88c560121b5-0-5" stroke-width="2px" d="M945,177.0 C945,89.5 1095.0,89.5 1095.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-90fdc7aa9cfd421ab57dc88c560121b5-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,179.0 L1103.0,167.0 1087.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-90fdc7aa9cfd421ab57dc88c560121b5-0-6" stroke-width="2px" d="M1120,177.0 C1120,89.5 1270.0,89.5 1270.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-90fdc7aa9cfd421ab57dc88c560121b5-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1270.0,179.0 L1278.0,167.0 1262.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-90fdc7aa9cfd421ab57dc88c560121b5-0-7" stroke-width="2px" d="M1295,177.0 C1295,89.5 1445.0,89.5 1445.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-90fdc7aa9cfd421ab57dc88c560121b5-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1445.0,179.0 L1453.0,167.0 1437.0,167.0" fill="currentColor"/>
# </g>
# </svg>
# </figure>
# </body>
# </html></span>
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /var/folders/7t/dq_q5_d944xbjbfpzcdd2p1w0000gn/T/ipykernel_80022/2986876254.py in <module>
# ----> 1 displacy.serve( nlp("which philosopher advocated the idea of return to nature"))
#
# ~/opt/anaconda3/envs/dnli/lib/python3.8/site-packages/spacy/displacy/__init__.py in serve(docs, style, page, minify, options, manual, port, host)
#      97         warnings.warn(Warnings.W011)
#      98     render(docs, style=style, page=page, minify=minify, options=options, manual=manual)
# ---> 99     httpd = simple_server.make_server(host, port, app)
#     100     print(f"\nUsing the '{style}' visualizer")
#     101     print(f"Serving on http://{host}:{port} ...\n")
#
# ~/opt/anaconda3/envs/dnli/lib/python3.8/wsgiref/simple_server.py in make_server(host, port, app, server_class, handler_class)
#     152 ):
#     153     """Create a new WSGI server listening on `host` and `port` for `app`"""
# --> 154     server = server_class((host, port), handler_class)
#     155     server.set_app(app)
#     156     return server
#
# ~/opt/anaconda3/envs/dnli/lib/python3.8/socketserver.py in __init__(self, server_address, RequestHandlerClass, bind_and_activate)
#     450         if bind_and_activate:
#     451             try:
# --> 452                 self.server_bind()
#     453                 self.server_activate()
#     454             except:
#
# ~/opt/anaconda3/envs/dnli/lib/python3.8/wsgiref/simple_server.py in server_bind(self)
#      48     def server_bind(self):
#      49         """Override server_bind to store the server name."""
# ---> 50         HTTPServer.server_bind(self)
#      51         self.setup_environ()
#      52
#
# ~/opt/anaconda3/envs/dnli/lib/python3.8/http/server.py in server_bind(self)
#     136     def server_bind(self):
#     137         """Override server_bind to store the server name."""
# --> 138         socketserver.TCPServer.server_bind(self)
#     139         host, port = self.server_address[:2]
#     140         self.server_name = socket.getfqdn(host)
#
# ~/opt/anaconda3/envs/dnli/lib/python3.8/socketserver.py in server_bind(self)
#     464         if self.allow_reuse_address:
#     465             self.socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# --> 466         self.socket.bind(self.server_address)
#     467         self.server_address = self.socket.getsockname()
#     468
#
# OSError: [Errno 48] Address already in use

# %%
check_comparative(nlp('my pyramid is a larger pyramid than the one in giza'))
# Out:
# (True, 'larger', 'pyramid')

# %%
for t in nlp("I would have been happier if I had a dog"):
    #print(t, t.dep_, t.tag_)
    
    if t.tag_ == 'IN' and str(t).lower() == 'if':
        for tok in t.head.subtree:
            print(tok.tag_, tok.lemma_)
# Out:
# IN if
# PRP I
# VBD have
# DT a
# NN dog

# %%
for t in nlp("when was the jury system abolished in india"):
    print(t, t.dep_, t.tag_)
    print()
# Out:
# when advmod WRB
#
# was aux VBD
#
# the det DT
#
# jury compound NN
#
# system nsubj NN
#
# abolished ROOT VBN
#
# in prep IN
#
# india pobj NNP
